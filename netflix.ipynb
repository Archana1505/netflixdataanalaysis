# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv("C:\\Users\\91939\\Downloads\\file.csv")

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data.describe()
# Out:
#        Show_Id Category              Title                Director  \
# count     7789     7789               7789                    5401
# unique    7787        2               7787                    4050
# top      s6621    Movie  The Lost Okoroshi  Raúl Campos, Jan Suter
# freq         2     5379                  2                      18
#
#                       Cast        Country     Release_Date Rating  Duration  \
# count                 7071           7282             7779   7782      7789
# unique                6831            681             1565     14       216
# top     David Attenborough  United States  January 1, 2020  TV-MA  1 Season
# freq                    18           2556              118   2865      1608
#
#                  Type                                        Description
# count            7789                                               7789
# unique            492                                               7769
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
data.drop_duplicates(inplace=True)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
data.shape
# Out:
# (7787, 11)

# %%
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data[data["Title"].isin(["House of Cards"])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
data["Release_Date"].dtypes
# Out:
# dtype('O')

# %%
data['Release_Date'] = data['Release_Date'].str.strip()
data['Release_Year'] = pd.to_datetime(data['Release_Date']).dt.year

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data["Release_Year"].value_counts().plot(kind="bar")
plt.show()

# %%
data["Category"].value_counts().plot(kind="bar")
plt.show()

# %%
data[data["Release_Year"].isin([2017])]
# Out:
#      Show_Id Category                              Title          Director  \
# 3         s4    Movie                                  9       Shane Acker
# 5         s6  TV Show                                 46       Serdar Akar
# 9        s10    Movie                               1920      Vikram Bhatt
# 10       s11    Movie                               1922      Zak Hilditch
# 33       s34    Movie                       #realityhigh  Fernando Lebrija
# ...      ...      ...                                ...               ...
# 7745   s7744  TV Show                    Yours Fatefully               NaN
# 7755   s7754  TV Show                         Yunus Emre               NaN
# 7763   s7762    Movie                             Zapped     Peter DeLuise
# 7768   s7767  TV Show                       Zig & Sharko               NaN
# 7774   s7773    Movie  Zipi & Zape y la Isla del Capitan      Oskar Santos
#
#                                                    Cast  \
# ...

# %% [markdown]
# FILTERING

# %%
data[(data['Category'] == 'Movie') & (data['Release_Year'] == 2018)]
# Out:
#      Show_Id Category                     Title          Director  \
# 2         s3    Movie                     23:59      Gilbert Chan
# 17       s18    Movie                    22-Jul   Paul Greengrass
# 19       s20    Movie                       '89               NaN
# 20       s21    Movie      ​​Kuch Bheege Alfaaz              Onir
# 21       s22    Movie              ​Goli Soda 2      Vijay Milton
# ...      ...      ...                       ...               ...
# 7765   s7764    Movie                     Zenda    Avadhoot Gupte
# 7770   s7769    Movie  Zindagi Kitni Haseen Hay     Anjum Shahzad
# 7773   s7772    Movie                      Zion        Floyd Russ
# 7778   s7777    Movie                  Zokkomon  Satyajit Bhatkal
# 7782   s7781    Movie                       Zoo      Shlok Sharma
#
#                                                    Cast  \
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 17    Anders Danielsen Lie, Jon Øigarden, Jonas Stra...
# ...

# %%
data[(data['Country'] == 'India') & (data['Release_Year'] == 2018)]
# Out:
#      Show_Id Category                 Title           Director  \
# 20       s21    Movie  ​​Kuch Bheege Alfaaz               Onir
# 21       s22    Movie          ​Goli Soda 2       Vijay Milton
# 22       s23    Movie    ​Maj Rati ​​Keteki  Santwana Bardoloi
# 23       s24    Movie           ​Mayurakshi        Atanu Ghosh
# 78       s79    Movie              2 States    Abhishek Varman
# ...      ...      ...                   ...                ...
# 7705   s7704  TV Show       Yeh Meri Family                NaN
# 7756   s7755    Movie                  Yuva        Mani Ratnam
# 7765   s7764    Movie                 Zenda     Avadhoot Gupte
# 7778   s7777    Movie              Zokkomon   Satyajit Bhatkal
# 7782   s7781    Movie                   Zoo       Shlok Sharma
#
#                                                    Cast Country  \
# 20    Geetanjali Thapa, Zain Khan Durrani, Shray Rai...   India
# 21    Samuthirakani, Bharath Seeni, Vinoth, Esakki B...   India
# ...

# %% [markdown]
# top 10 directors with highest number of tv and movies given to netflix

# %%
data["Director"].value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: count, dtype: int64

# %%
data[(data['Type'] == 'Comedies') & (data["Country"] == "United States")]
# Out:
#      Show_Id Category                                              Title  \
# 33       s34    Movie                                       #realityhigh
# 72       s73    Movie                                           17 Again
# 84       s85    Movie                                          21 & Over
# 174     s175    Movie                        A Futile and Stupid Gesture
# 240     s241    Movie                                   A Thousand Words
# ...      ...      ...                                                ...
# 7321   s7320    Movie  Unbreakable Kimmy Schmidt: Kimmy vs. the Reverend
# 7341   s7340    Movie                               Undercover Brother 2
# 7590   s7589    Movie                                  Where's the Money
# 7634   s7633    Movie                                       Wine Country
# 7664   s7663    Movie                                            Work It
#
#                     Director  \
# 33          Fernando Lebrija
# ...

# %%
data[data['Cast']=="Tom Cruise"]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Release_Year]
# Index: []

# %%
new_data=data.dropna()

# %%
new_data.shape
# Out:
# (4809, 12)

# %%
new_data[new_data["Cast"].str.contains("Tom Cruise")]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description  Release_Year
# 3860  Through chance, human action, past history and...        2020.0
# 5071  A fast-talking yuppie is forced to slow down w...        2019.0

# %%
new_data["Rating"].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
new_data[(new_data['Rating'] == 'TV-MA') & (new_data["Country"] == "United States")].shape
# Out:
# (515, 12)

# %%
new_data["Rating"].value_counts()
# Out:
# Rating
# TV-MA       1666
# TV-14       1133
# R            654
# TV-PG        413
# PG-13        375
# PG           238
# TV-G          80
# TV-Y          71
# TV-Y7         69
# NR            62
# G             38
# UR             5
# TV-Y7-FV       3
# NC-17          2
# Name: count, dtype: int64

# %%
data_tvshow=new_data[new_data['Category']== "TV Show"]
data_tvshow.Country.value_counts().head(10)
# Out:
# Country
# United States     27
# United Kingdom    19
# Japan             10
# South Korea       10
# Spain              7
# Taiwan             6
# Turkey             5
# India              5
# Brazil             4
# Canada             3
# Name: count, dtype: int64

# %%
data_tvshow.Country.value_counts().head(10).plot(kind="bar")
plt.show()

# %%
data_movie=new_data[new_data['Category']== "Movie"]
data_movie.Country.value_counts().head(10).plot(kind="bar")
plt.show()

# %%
cols=list(data_movie.Country.value_counts().head(10).values)
ind=list(data_movie.Country.value_counts().head(10).index)
plt.pie(cols,labels=ind,autopct="%2.2f%%")
plt.title("countries watching movies")
plt.show()
